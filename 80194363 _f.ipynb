# %%
import pandas as pd
import numpy as np

# %%
import 80194363.zip as z:
print(z.namelist())

with z.open('80194363.csv')as f:
  df=pd.read_csv(f)
# Out:
#   File "/tmp/ipykernel_14416/864848602.py", line 1
#     import 80194363.zip) as z:
#                    ^
# SyntaxError: invalid decimal literal

# %%
## Is there a company that has no difference between the High and Low columnsfor any trading day? What does it mean for the stock’s trading behavior on suchdays
df['High']==df['Low']

# %%
#What is the highest and lowest price price each company recorded? Hint:Select the column(s) that can contain the maximum and minimum price wisely.
highest_value=max(df['High'])
lowest_value=min(df['Low'])
print(highest_value)
print(lowest_value)

# %%
# Calculate logarithmic returns from Close. For each company, report min,max, mean, standard deviation, and skewness of returns.
log_returns=np.log(df['Close'])
log_returns.min()
log_returns.max()
log_returns.std()
log_returns.mean()
log_returns.skew()

# %%
#When (date) did each company record the second highest gain and secondhighest loss (in terms of logarithmic returns)? Hint: idxmax.
idmax=log_returns.idmax()
idmin=log_returns.idmin()

# %%
#What is the median calendar weekly volume (i.e. sum of volume for a particular week) for each company? Hint: check resample.
weekly_volume=df['volume'].resample('weekly').sum()
weekly_valume.median()
# Out:
#   File "/tmp/ipykernel_14416/3014425367.py", line 2
#     help(?)
#          ^
# SyntaxError: invalid syntax

# %%
#Which company recorded the lowest total logarithmic return over the wholeperiod?

lowest_total_logrithmic_return=log_return.min()

# %%
#Create a new column volume_class with categories (e.g., “Low”, “Medium”,“High”) based on volume tertiles within the given company.
volume_class=pd.qcut(df['volume'],3,labels=['low','medium','high']

# %%
#8. (2 pt) (A) Plot the log-returns of the companies (ideally in the same plot). (B) Plot the distribution of log-returns (ideally in the same plot).
plt.plot(log_returns)
plot.show()
plt.hist(log_returns)
plot.show()

# %%
#task2

# %%
#1. (1 pt) How many companies have missing inclusion dates (included column)?
df.isna()

# %%
#REMOVE
